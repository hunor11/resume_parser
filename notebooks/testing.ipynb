# %%
import os 
import sys 

sys.path.append(os.path.abspath("../backend/")) 

from app.services.parsing_service import ParsingService

# %%
ps = ParsingService(data_dir="../data/resumes", chunk_size=500, chunk_overlap=50)

# %%
ps.parse_directory()
# Out:
# {'resume_489.txt': 2,
#  'resume_338.txt': 4,
#  'resume_304.txt': 9,
#  'resume_462.txt': 17,
#  'resume_476.txt': 6,
#  'resume_310.txt': 9,
#  'resume_847.txt': 7,
#  'resume_853.txt': 7,
#  'resume_884.txt': 4,
#  'resume_890.txt': 10,
#  'resume_648.txt': 14,
#  'resume_660.txt': 12,
#  'resume_106.txt': 21,
#  'resume_112.txt': 21,
#  'resume_674.txt': 9,
#  'resume_933.txt': 6,
#  'resume_927.txt': 2,
#  'resume_21.txt': 4,
#  'resume_35.txt': 2,
#  'resume_728.txt': 8,
#  'resume_714.txt': 10,
#  'resume_700.txt': 15,
#  'resume_258.txt': 5,
#  'resume_270.txt': 9,
#  'resume_516.txt': 20,
#  'resume_502.txt': 1,
#  'resume_264.txt': 3,
#  'resume_503.txt': 12,
#  'resume_265.txt': 2,
#  'resume_271.txt': 2,
#  'resume_517.txt': 40,
#  'resume_259.txt': 3,
#  'resume_701.txt': 21,
#  'resume_715.txt': 13,
#  'resume_729.txt': 11,
#  'resume_34.txt': 1,
#  'resume_20.txt': 15,
#  'resume_926.txt': 6,
#  'resume_932.txt': 3,
#  'resume_113.txt': 1,
#  'resume_675.txt': 12,
#  'resume_661.txt': 7,
#  'resume_107.txt': 1,
#  'resume_649.txt': 5,
#  'resume_891.txt': 7,
#  'resume_885.txt': 10,
#  'resume_852.txt': 4,
#  'resume_846.txt': 2,
#  'resume_477.txt': 17,
#  'resume_311.txt': 9,
#  'resume_305.txt': 9,
#  'resume_463.txt': 6,
#  'resume_339.txt': 4,
#  'resume_488.txt': 12,
#  'resume_449.txt': 13,
#  'resume_313.txt': 19,
#  'resume_475.txt': 17,
#  'resume_461.txt': 3,
#  'resume_307.txt': 19,
#  'resume_688.txt': 15,
#  'resume_850.txt': 20,
#  'resume_844.txt': 4,
#  'resume_878.txt': 7,
#  'resume_893.txt': 5,
#  'resume_139.txt': 4,
#  'resume_887.txt': 4,
#  'resume_677.txt': 10,
#  'resume_111.txt': 4,
#  'resume_105.txt': 4,
#  'resume_663.txt': 17,
#  'resume_924.txt': 8,
#  'resume_930.txt': 6,
#  'resume_36.txt': 6,
#  'resume_918.txt': 3,
#  'resume_22.txt': 5,
#  'resume_703.txt': 15,
#  'resume_717.txt': 8,
#  'resume_298.txt': 9,
#  'resume_529.txt': 40,
#  'resume_267.txt': 7,
#  'resume_501.txt': 12,
#  'resume_515.txt': 36,
#  'resume_273.txt': 7,
#  'resume_514.txt': 50,
#  'resume_272.txt': 3,
#  'resume_266.txt': 3,
#  'resume_500.txt': 6,
#  'resume_528.txt': 20,
#  'resume_299.txt': 9,
#  'resume_716.txt': 9,
#  'resume_702.txt': 7,
#  'resume_23.txt': 19,
#  'resume_919.txt': 6,
#  'resume_37.txt': 19,
#  'resume_931.txt': 8,
#  'resume_925.txt': 3,
#  'resume_104.txt': 7,
#  'resume_662.txt': 10,
#  'resume_676.txt': 7,
#  'resume_110.txt': 7,
#  'resume_138.txt': 2,
#  'resume_886.txt': 7,
#  'resume_892.txt': 2,
#  'resume_879.txt': 4,
#  'resume_845.txt': 3,
#  'resume_851.txt': 4,
#  'resume_689.txt': 21,
#  'resume_460.txt': 15,
#  'resume_306.txt': 2,
#  'resume_312.txt': 2,
#  'resume_474.txt': 3,
#  'resume_448.txt': 7,
#  'resume_470.txt': 13,
#  'resume_316.txt': 9,
#  'resume_302.txt': 1,
#  'resume_464.txt': 17,
#  'resume_458.txt': 17,
#  'resume_869.txt': 4,
#  'resume_855.txt': 10,
#  'resume_699.txt': 7,
#  'resume_841.txt': 1,
#  'resume_114.txt': 2,
#  'resume_672.txt': 10,
#  'resume_666.txt': 7,
#  'resume_100.txt': 2,
#  'resume_128.txt': 7,
#  'resume_896.txt': 8,
#  'resume_882.txt': 4,
#  'resume_33.txt': 19,
#  'resume_909.txt': 6,
#  'resume_27.txt': 19,
#  'resume_921.txt': 5,
#  'resume_935.txt': 5,
#  'resume_706.txt': 15,
#  'resume_712.txt': 10,
#  'resume_289.txt': 2,
#  'resume_504.txt': 2,
#  'resume_262.txt': 11,
#  'resume_276.txt': 9,
#  'resume_510.txt': 6,
#  'resume_538.txt': 50,
#  'resume_539.txt': 36,
#  'resume_277.txt': 2,
#  'resume_511.txt': 36,
#  'resume_505.txt': 6,
#  'resume_263.txt': 5,
#  'resume_288.txt': 9,
#  'resume_713.txt': 8,
#  'resume_707.txt': 21,
#  'resume_934.txt': 2,
#  'resume_920.txt': 2,
#  'resume_26.txt': 6,
#  'resume_908.txt': 6,
#  'resume_32.txt': 5,
#  'resume_883.txt': 7,
#  'resume_129.txt': 4,
#  'resume_897.txt': 3,
#  'resume_667.txt': 10,
#  'resume_101.txt': 3,
#  'resume_115.txt': 4,
#  'resume_673.txt': 17,
#  'resume_840.txt': 7,
#  'resume_698.txt': 21,
#  'resume_854.txt': 4,
#  'resume_868.txt': 7,
#  'resume_459.txt': 6,
#  'resume_303.txt': 10,
#  'resume_465.txt': 6,
#  'resume_471.txt': 17,
#  'resume_317.txt': 9,
#  'resume_498.txt': 12,
#  'resume_467.txt': 6,
#  'resume_301.txt': 19,
#  'resume_315.txt': 10,
#  'resume_473.txt': 15,
#  'resume_329.txt': 3,
#  'resume_842.txt': 11,
#  'resume_856.txt': 7,
#  'resume_103.txt': 1,
#  'resume_665.txt': 12,
#  'resume_671.txt': 7,
#  'resume_117.txt': 4,
#  'resume_881.txt': 7,
#  'resume_659.txt': 9,
#  'resume_895.txt': 6,
#  'resume_24.txt': 1,
#  'resume_30.txt': 15,
#  'resume_18.txt': 5,
#  'resume_936.txt': 6,
#  'resume_922.txt': 6,
#  'resume_711.txt': 13,
#  'resume_705.txt': 7,
#  'resume_739.txt': 8,
#  'resume_513.txt': 40,
#  'resume_275.txt': 5,
#  'resume_261.txt': 3,
#  'resume_507.txt': 1,
#  'resume_249.txt': 3,
#  'resume_248.txt': 5,
#  'resume_260.txt': 3,
#  'resume_506.txt': 12,
#  'resume_512.txt': 20,
#  'resume_274.txt': 7,
#  'resume_738.txt': 9,
#  'resume_704.txt': 21,
#  'resume_710.txt': 11,
#  'resume_923.txt': 6,
#  'resume_937.txt': 6,
#  'resume_19.txt': 12,
#  'resume_31.txt': 4,
#  'resume_25.txt': 2,
#  'resume_894.txt': 6,
#  'resume_658.txt': 17,
#  'resume_880.txt': 10,
#  'resume_670.txt': 12,
#  'resume_116.txt': 7,
#  'resume_102.txt': 2,
#  'resume_664.txt': 9,
#  'resume_857.txt': 4,
#  'resume_843.txt': 20,
#  'resume_328.txt': 2,
#  'resume_314.txt': 1,
#  'resume_472.txt': 6,
#  'resume_466.txt': 17,
#  'resume_300.txt': 2,
#  'resume_499.txt': 2,
#  'resume_398.txt': 2,
#  'resume_429.txt': 5,
#  'resume_401.txt': 2,
#  'resume_367.txt': 4,
#  'resume_373.txt': 2,
#  'resume_415.txt': 5,
#  'resume_824.txt': 3,
#  'resume_830.txt': 4,
#  'resume_818.txt': 3,
#  'resume_159.txt': 11,
#  'resume_165.txt': 9,
#  'resume_603.txt': 13,
#  'resume_617.txt': 16,
#  'resume_171.txt': 11,
#  'resume_950.txt': 6,
#  'resume_788.txt': 3,
#  'resume_944.txt': 6,
#  'resume_42.txt': 1,
#  'resume_56.txt': 1,
#  'resume_777.txt': 11,
#  'resume_81.txt': 2,
#  'resume_95.txt': 1,
#  'resume_763.txt': 11,
#  'resume_549.txt': 40,
#  'resume_575.txt': 9,
#  'resume_213.txt': 7,
#  'resume_207.txt': 2,
#  'resume_561.txt': 7,
#  'resume_206.txt': 6,
#  'resume_560.txt': 9,
#  'resume_574.txt': 4,
#  'resume_212.txt': 2,
#  'resume_548.txt': 20,
#  'resume_762.txt': 18,
#  'resume_94.txt': 5,
#  'resume_80.txt': 3,
#  'resume_776.txt': 18,
#  'resume_57.txt': 1,
#  'resume_43.txt': 1,
#  'resume_945.txt': 8,
#  'resume_789.txt': 11,
#  'resume_951.txt': 6,
#  'resume_616.txt': 5,
#  'resume_170.txt': 9,
#  'resume_164.txt': 11,
#  'resume_602.txt': 22,
#  'resume_158.txt': 2,
#  'resume_819.txt': 11,
#  'resume_831.txt': 3,
#  'resume_825.txt': 2,
#  'resume_372.txt': 12,
#  'resume_414.txt': 33,
#  'resume_400.txt': 12,
#  'resume_366.txt': 4,
#  'resume_428.txt': 33,
#  'resume_399.txt': 3,
#  'resume_358.txt': 12,
#  'resume_416.txt': 5,
#  'resume_370.txt': 2,
#  'resume_364.txt': 6,
#  'resume_402.txt': 6,
#  'resume_833.txt': 7,
#  'resume_827.txt': 1,
#  'resume_199.txt': 4,
#  'resume_628.txt': 5,
#  'resume_172.txt': 9,
#  'resume_614.txt': 16,
#  'resume_600.txt': 5,
#  'resume_166.txt': 11,
#  'resume_69.txt': 3,
#  'resume_947.txt': 6,
#  'resume_953.txt': 3,
#  'resume_55.txt': 1,
#  'resume_41.txt': 8,
#  'resume_748.txt': 18,
#  'resume_96.txt': 1,
#  'resume_760.txt': 18,
#  'resume_774.txt': 18,
#  'resume_82.txt': 3,
#  'resume_589.txt': 2,
#  'resume_238.txt': 5,
#  'resume_562.txt': 4,
#  'resume_204.txt': 4,
#  'resume_210.txt': 27,
#  'resume_576.txt': 1,
#  'resume_211.txt': 6,
#  'resume_577.txt': 2,
#  'resume_563.txt': 9,
#  'resume_205.txt': 27,
#  'resume_239.txt': 3,
#  'resume_588.txt': 1,
#  'resume_83.txt': 3,
#  'resume_775.txt': 4,
#  'resume_761.txt': 4,
#  'resume_97.txt': 3,
#  'resume_749.txt': 11,
#  'resume_40.txt': 1,
#  'resume_54.txt': 1,
#  'resume_952.txt': 8,
#  'resume_946.txt': 3,
#  'resume_68.txt': 1,
#  'resume_601.txt': 16,
#  'resume_167.txt': 9,
#  'resume_173.txt': 2,
#  'resume_615.txt': 14,
#  'resume_629.txt': 16,
#  'resume_826.txt': 7,
#  'resume_198.txt': 7,
#  'resume_832.txt': 2,
#  'resume_365.txt': 4,
#  'resume_403.txt': 7,
#  'resume_417.txt': 7,
#  'resume_371.txt': 3,
#  'resume_359.txt': 2,
#  'resume_375.txt': 1,
#  'resume_413.txt': 26,
#  'resume_407.txt': 5,
#  'resume_361.txt': 1,
#  'resume_349.txt': 6,
#  'resume_836.txt': 20,
#  'resume_188.txt': 7,
#  'resume_822.txt': 14,
#  'resume_611.txt': 16,
#  'resume_177.txt': 9,
#  'resume_163.txt': 2,
#  'resume_605.txt': 9,
#  'resume_639.txt': 14,
#  'resume_50.txt': 3,
#  'resume_44.txt': 1,
#  'resume_942.txt': 5,
#  'resume_956.txt': 5,
#  'resume_78.txt': 1,
#  'resume_93.txt': 1,
#  'resume_765.txt': 8,
#  'resume_771.txt': 6,
#  'resume_87.txt': 3,
#  'resume_759.txt': 10,
#  'resume_598.txt': 4,
#  'resume_9.txt': 12,
#  'resume_201.txt': 6,
#  'resume_567.txt': 7,
#  'resume_573.txt': 7,
#  'resume_215.txt': 27,
#  'resume_229.txt': 3,
#  'resume_228.txt': 5,
#  'resume_572.txt': 9,
#  'resume_214.txt': 4,
#  'resume_200.txt': 27,
#  'resume_566.txt': 9,
#  'resume_8.txt': 5,
#  'resume_599.txt': 14,
#  'resume_758.txt': 8,
#  'resume_86.txt': 1,
#  'resume_770.txt': 11,
#  'resume_764.txt': 6,
#  'resume_92.txt': 2,
#  'resume_79.txt': 1,
#  'resume_957.txt': 6,
#  'resume_943.txt': 6,
#  'resume_45.txt': 1,
#  'resume_51.txt': 1,
#  'resume_638.txt': 16,
#  'resume_162.txt': 9,
#  'resume_604.txt': 11,
#  'resume_610.txt': 5,
#  'resume_176.txt': 11,
#  'resume_823.txt': 3,
#  'resume_837.txt': 4,
#  'resume_189.txt': 4,
#  'resume_348.txt': 6,
#  'resume_406.txt': 33,
#  'resume_360.txt': 6,
#  'resume_374.txt': 6,
#  'resume_412.txt': 5,
#  'resume_389.txt': 1,
#  'resume_362.txt': 6,
#  'resume_404.txt': 6,
#  'resume_410.txt': 33,
#  'resume_376.txt': 6,
#  'resume_438.txt': 26,
#  'resume_809.txt': 11,
#  'resume_821.txt': 5,
#  'resume_835.txt': 11,
#  'resume_606.txt': 14,
#  'resume_160.txt': 9,
#  'resume_174.txt': 11,
#  'resume_612.txt': 14,
#  'resume_148.txt': 2,
#  'resume_47.txt': 3,
#  'resume_53.txt': 1,
#  'resume_955.txt': 2,
#  'resume_941.txt': 2,
#  'resume_799.txt': 11,
#  'resume_772.txt': 8,
#  'resume_84.txt': 5,
#  'resume_90.txt': 2,
#  'resume_766.txt': 10,
#  'resume_216.txt': 6,
#  'resume_570.txt': 1,
#  'resume_564.txt': 1,
#  'resume_202.txt': 2,
#  'resume_558.txt': 1,
#  'resume_559.txt': 2,
#  'resume_565.txt': 2,
#  'resume_203.txt': 7,
#  'resume_217.txt': 2,
#  'resume_571.txt': 2,
#  'resume_767.txt': 18,
#  'resume_91.txt': 3,
#  'resume_85.txt': 1,
#  'resume_773.txt': 10,
#  'resume_798.txt': 3,
#  'resume_940.txt': 6,
#  'resume_954.txt': 6,
#  'resume_52.txt': 8,
#  'resume_46.txt': 1,
#  'resume_149.txt': 11,
#  'resume_175.txt': 9,
#  'resume_613.txt': 5,
#  'resume_607.txt': 5,
#  'resume_161.txt': 11,
#  'resume_834.txt': 1,
#  'resume_820.txt': 14,
#  'resume_808.txt': 3,
#  'resume_439.txt': 10,
#  'resume_411.txt': 5,
#  'resume_377.txt': 6,
#  'resume_363.txt': 6,
#  'resume_405.txt': 26,
#  'resume_388.txt': 6,
#  'resume_385.txt': 3,
#  'resume_391.txt': 6,
#  'resume_408.txt': 5,
#  'resume_420.txt': 33,
#  'resume_346.txt': 6,
#  'resume_352.txt': 4,
#  'resume_434.txt': 4,
#  'resume_805.txt': 14,
#  'resume_811.txt': 5,
#  'resume_187.txt': 2,
#  'resume_839.txt': 2,
#  'resume_193.txt': 7,
#  'resume_178.txt': 2,
#  'resume_144.txt': 11,
#  'resume_622.txt': 5,
#  'resume_636.txt': 14,
#  'resume_150.txt': 9,
#  'resume_795.txt': 14,
#  'resume_63.txt': 8,
#  'resume_77.txt': 1,
#  'resume_959.txt': 8,
#  'resume_781.txt': 18,
#  'resume_88.txt': 9,
#  'resume_756.txt': 11,
#  'resume_742.txt': 11,
#  'resume_597.txt': 7,
#  'resume_583.txt': 2,
#  'resume_6.txt': 6,
#  'resume_568.txt': 4,
#  'resume_554.txt': 9,
#  'resume_232.txt': 11,
#  'resume_226.txt': 3,
#  'resume_540.txt': 20,
#  'resume_227.txt': 11,
#  'resume_541.txt': 40,
#  'resume_555.txt': 7,
#  'resume_233.txt': 5,
#  'resume_569.txt': 9,
#  'resume_7.txt': 19,
#  'resume_582.txt': 1,
#  'resume_596.txt': 9,
#  'resume_743.txt': 6,
#  'resume_757.txt': 6,
#  'resume_89.txt': 2,
#  'resume_780.txt': 10,
#  'resume_958.txt': 6,
#  'resume_76.txt': 1,
#  'resume_62.txt': 1,
#  'resume_794.txt': 11,
#  'resume_637.txt': 5,
#  'resume_151.txt': 11,
#  'resume_145.txt': 9,
#  'resume_623.txt': 16,
#  'resume_179.txt': 11,
#  'resume_192.txt': 2,
#  'resume_186.txt': 6,
#  'resume_838.txt': 3,
#  'resume_810.txt': 14,
#  'resume_804.txt': 11,
#  'resume_353.txt': 4,
#  'resume_435.txt': 3,
#  'resume_421.txt': 5,
#  'resume_347.txt': 1,
#  'resume_409.txt': 26,
#  'resume_390.txt': 6,
#  'resume_384.txt': 2,
#  'resume_392.txt': 6,
#  'resume_386.txt': 12,
#  'resume_379.txt': 4,
#  'resume_437.txt': 13,
#  'resume_351.txt': 4,
#  'resume_345.txt': 2,
#  'resume_423.txt': 26,
#  'resume_812.txt': 14,
#  'resume_806.txt': 5,
#  'resume_190.txt': 27,
#  'resume_184.txt': 11,
#  'resume_609.txt': 14,
#  'resume_153.txt': 2,
#  'resume_635.txt': 16,
#  'resume_621.txt': 14,
#  'resume_147.txt': 9,
#  'resume_48.txt': 2,
#  'resume_74.txt': 8,
#  'resume_782.txt': 4,
#  'resume_796.txt': 5,
#  'resume_60.txt': 3,
#  'resume_769.txt': 18,
#  'resume_741.txt': 7,
#  'resume_755.txt': 18,
#  'resume_580.txt': 4,
#  'resume_5.txt': 2,
#  'resume_594.txt': 1,
#  'resume_219.txt': 4,
#  'resume_543.txt': 36,
#  'resume_225.txt': 3,
#  'resume_231.txt': 3,
#  'resume_557.txt': 9,
#  'resume_230.txt': 3,
#  'resume_556.txt': 4,
#  'resume_542.txt': 50,
#  'resume_224.txt': 4,
#  'resume_218.txt': 7,
#  'resume_595.txt': 2,
#  'resume_4.txt': 1,
#  'resume_581.txt': 9,
#  'resume_754.txt': 4,
#  'resume_740.txt': 11,
#  'resume_768.txt': 4,
#  'resume_61.txt': 3,
#  'resume_797.txt': 14,
#  'resume_783.txt': 18,
#  'resume_75.txt': 1,
#  'resume_49.txt': 3,
#  'resume_620.txt': 16,
#  'resume_146.txt': 11,
#  'resume_152.txt': 9,
#  'resume_634.txt': 5,
#  'resume_608.txt': 16,
#  'resume_185.txt': 27,
#  'resume_191.txt': 6,
#  'resume_807.txt': 14,
#  'resume_813.txt': 3,
#  'resume_344.txt': 12,
#  'resume_422.txt': 5,
#  'resume_436.txt': 7,
#  'resume_350.txt': 6,
#  'resume_378.txt': 6,
#  'resume_387.txt': 2,
#  'resume_393.txt': 4,
#  'resume_397.txt': 6,
#  'resume_383.txt': 6,
#  'resume_354.txt': 4,
#  'resume_432.txt': 26,
#  'resume_426.txt': 5,
#  'resume_340.txt': 4,
#  'resume_368.txt': 4,
#  'resume_195.txt': 27,
#  'resume_181.txt': 11,
#  'resume_817.txt': 14,
#  'resume_803.txt': 3,
#  'resume_630.txt': 14,
#  'resume_156.txt': 11,
#  'resume_142.txt': 9,
#  'resume_624.txt': 14,
#  'resume_618.txt': 14,
#  'resume_71.txt': 3,
#  'resume_787.txt': 14,
#  'resume_793.txt': 3,
#  'resume_65.txt': 1,
#  'resume_59.txt': 2,
#  'resume_744.txt': 8,
#  'resume_750.txt': 6,
#  'resume_778.txt': 6,
#  'resume_585.txt': 7,
#  'resume_0.txt': 15,
#  'resume_591.txt': 7,
#  'resume_220.txt': 27,
#  'resume_546.txt': 50,
#  'resume_552.txt': 1,
#  'resume_234.txt': 3,
#  'resume_208.txt': 7,
#  'resume_209.txt': 4,
#  'resume_553.txt': 2,
#  'resume_235.txt': 3,
#  'resume_221.txt': 6,
#  'resume_547.txt': 36,
#  'resume_590.txt': 9,
#  'resume_1.txt': 4,
#  'resume_584.txt': 9,
#  'resume_779.txt': 8,
#  'resume_751.txt': 8,
#  'resume_745.txt': 10,
#  'resume_58.txt': 3,
#  'resume_64.txt': 1,
#  'resume_792.txt': 14,
#  'resume_786.txt': 5,
#  'resume_70.txt': 2,
#  'resume_619.txt': 5,
#  'resume_143.txt': 2,
#  'resume_625.txt': 5,
#  'resume_631.txt': 5,
#  'resume_157.txt': 9,
#  'resume_802.txt': 14,
#  'resume_816.txt': 5,
#  'resume_180.txt': 9,
#  'resume_194.txt': 4,
#  'resume_369.txt': 6,
#  'resume_427.txt': 26,
#  'resume_341.txt': 6,
#  'resume_355.txt': 6,
#  'resume_433.txt': 10,
#  'resume_382.txt': 4,
#  'resume_396.txt': 4,
#  'resume_380.txt': 4,
#  'resume_394.txt': 4,
#  'resume_343.txt': 3,
#  'resume_425.txt': 5,
#  'resume_431.txt': 13,
#  'resume_357.txt': 3,
#  'resume_419.txt': 26,
#  'resume_182.txt': 9,
#  'resume_196.txt': 6,
#  'resume_828.txt': 11,
#  'resume_800.txt': 14,
#  'resume_814.txt': 11,
#  'resume_627.txt': 14,
#  'resume_141.txt': 11,
#  'resume_155.txt': 9,
#  'resume_633.txt': 14,
#  'resume_169.txt': 11,
#  'resume_948.txt': 2,
#  'resume_790.txt': 14,
#  'resume_66.txt': 1,
#  'resume_72.txt': 3,
#  'resume_784.txt': 11,
#  'resume_960.txt': 3,
#  'resume_753.txt': 18,
#  'resume_747.txt': 4,
#  'resume_99.txt': 2,
#  'resume_592.txt': 4,
#  'resume_586.txt': 4,
#  'resume_3.txt': 19,
#  'resume_237.txt': 11,
#  'resume_551.txt': 9,
#  'resume_545.txt': 40,
#  'resume_223.txt': 7,
#  'resume_579.txt': 7,
#  'resume_578.txt': 9,
#  'resume_544.txt': 20,
#  'resume_222.txt': 2,
#  'resume_236.txt': 3,
#  'resume_550.txt': 50,
#  'resume_2.txt': 5,
#  'resume_587.txt': 9,
#  'resume_593.txt': 9,
#  'resume_98.txt': 9,
#  'resume_746.txt': 18,
#  'resume_752.txt': 10,
#  'resume_961.txt': 6,
#  'resume_785.txt': 14,
#  'resume_73.txt': 1,
#  'resume_67.txt': 1,
#  'resume_791.txt': 5,
#  'resume_949.txt': 5,
#  'resume_168.txt': 2,
#  'resume_154.txt': 11,
#  'resume_632.txt': 16,
#  'resume_626.txt': 16,
#  'resume_140.txt': 9,
#  'resume_815.txt': 14,
#  'resume_801.txt': 5,
#  'resume_197.txt': 2,
#  'resume_829.txt': 20,
#  'resume_183.txt': 2,
#  'resume_418.txt': 6,
#  'resume_430.txt': 5,
#  'resume_356.txt': 2,
#  'resume_342.txt': 2,
#  'resume_424.txt': 33,
#  'resume_395.txt': 4,
#  'resume_381.txt': 4,
#  'resume_480.txt': 6,
#  'resume_494.txt': 2,
#  'resume_319.txt': 1,
#  'resume_325.txt': 4,
#  'resume_443.txt': 13,
#  'resume_457.txt': 13,
#  'resume_331.txt': 2,
#  'resume_866.txt': 7,
#  'resume_872.txt': 4,
#  'resume_682.txt': 15,
#  'resume_696.txt': 7,
#  'resume_669.txt': 9,
#  'resume_899.txt': 2,
#  'resume_641.txt': 16,
#  'resume_127.txt': 4,
#  'resume_133.txt': 4,
#  'resume_655.txt': 12,
#  'resume_912.txt': 6,
#  'resume_28.txt': 5,
#  'resume_906.txt': 2,
#  'resume_14.txt': 1,
#  'resume_709.txt': 13,
#  'resume_735.txt': 8,
#  'resume_721.txt': 11,
#  'resume_292.txt': 7,
#  'resume_286.txt': 7,
#  'resume_279.txt': 7,
#  'resume_251.txt': 3,
#  'resume_537.txt': 40,
#  'resume_523.txt': 36,
#  'resume_245.txt': 3,
#  'resume_522.txt': 50,
#  'resume_244.txt': 3,
#  'resume_250.txt': 3,
#  'resume_536.txt': 20,
#  'resume_278.txt': 3,
#  'resume_287.txt': 5,
#  'resume_293.txt': 5,
#  'resume_720.txt': 13,
#  'resume_734.txt': 10,
#  'resume_708.txt': 7,
#  'resume_15.txt': 2,
#  'resume_907.txt': 5,
#  'resume_29.txt': 12,
#  'resume_913.txt': 2,
#  'resume_132.txt': 2,
#  'resume_654.txt': 9,
#  'resume_640.txt': 5,
#  'resume_898.txt': 6,
#  'resume_126.txt': 2,
#  'resume_668.txt': 17,
#  'resume_697.txt': 15,
#  'resume_683.txt': 21,
#  'resume_873.txt': 7,
#  'resume_867.txt': 4,
#  'resume_456.txt': 13,
#  'resume_330.txt': 12,
#  'resume_324.txt': 4,
#  'resume_442.txt': 7,
#  'resume_318.txt': 2,
#  'resume_495.txt': 6,
#  'resume_481.txt': 12,
#  'resume_497.txt': 1,
#  'resume_483.txt': 12,
#  'resume_468.txt': 8,
#  'resume_332.txt': 6,
#  'resume_454.txt': 7,
#  'resume_440.txt': 4,
#  'resume_326.txt': 4,
#  'resume_871.txt': 7,
#  'resume_865.txt': 10,
#  'resume_695.txt': 21,
#  'resume_681.txt': 7,
#  'resume_859.txt': 4,
#  'resume_118.txt': 21,
#  'resume_656.txt': 7,
#  'resume_130.txt': 21,
#  'resume_124.txt': 21,
#  'resume_642.txt': 14,
#  'resume_905.txt': 6,
#  'resume_911.txt': 3,
#  'resume_939.txt': 3,
#  'resume_17.txt': 19,
#  'resume_722.txt': 13,
#  'resume_736.txt': 10,
#  'resume_285.txt': 7,
#  'resume_291.txt': 7,
#  'resume_508.txt': 12,
#  'resume_246.txt': 3,
#  'resume_520.txt': 20,
#  'resume_534.txt': 50,
#  'resume_252.txt': 11,
#  'resume_535.txt': 36,
#  'resume_253.txt': 5,
#  'resume_247.txt': 11,
#  'resume_521.txt': 40,
#  'resume_509.txt': 2,
#  'resume_290.txt': 3,
#  'resume_284.txt': 3,
#  'resume_737.txt': 13,
#  'resume_723.txt': 10,
#  'resume_16.txt': 6,
#  'resume_938.txt': 8,
#  'resume_910.txt': 8,
#  'resume_904.txt': 3,
#  'resume_125.txt': 1,
#  'resume_643.txt': 5,
#  'resume_657.txt': 10,
#  'resume_131.txt': 1,
#  'resume_119.txt': 1,
#  'resume_858.txt': 7,
#  'resume_680.txt': 21,
#  'resume_694.txt': 15,
#  'resume_864.txt': 4,
#  'resume_870.txt': 10,
#  'resume_441.txt': 3,
#  'resume_327.txt': 6,
#  'resume_333.txt': 1,
#  'resume_455.txt': 8,
#  'resume_469.txt': 13,
#  'resume_482.txt': 1,
#  'resume_496.txt': 12,
#  'resume_492.txt': 1,
#  'resume_486.txt': 12,
#  'resume_451.txt': 10,
#  'resume_337.txt': 4,
#  'resume_323.txt': 4,
#  'resume_445.txt': 10,
#  'resume_479.txt': 17,
#  'resume_690.txt': 7,
#  'resume_848.txt': 1,
#  'resume_684.txt': 7,
#  'resume_874.txt': 4,
#  'resume_860.txt': 10,
#  'resume_135.txt': 4,
#  'resume_653.txt': 16,
#  'resume_647.txt': 16,
#  'resume_121.txt': 4,
#  'resume_109.txt': 4,
#  'resume_12.txt': 5,
#  'resume_928.txt': 5,
#  'resume_900.txt': 5,
#  'resume_914.txt': 5,
#  'resume_727.txt': 9,
#  'resume_733.txt': 13,
#  'resume_280.txt': 7,
#  'resume_294.txt': 9,
#  'resume_525.txt': 40,
#  'resume_243.txt': 5,
#  'resume_257.txt': 11,
#  'resume_531.txt': 36,
#  'resume_519.txt': 36,
#  'resume_518.txt': 50,
#  'resume_256.txt': 3,
#  'resume_530.txt': 50,
#  'resume_524.txt': 20,
#  'resume_242.txt': 11,
#  'resume_295.txt': 19,
#  'resume_281.txt': 5,
#  'resume_732.txt': 11,
#  'resume_726.txt': 13,
#  'resume_915.txt': 6,
#  'resume_901.txt': 6,
#  'resume_929.txt': 6,
#  'resume_13.txt': 19,
#  'resume_108.txt': 2,
#  'resume_646.txt': 5,
#  'resume_120.txt': 2,
#  'resume_134.txt': 7,
#  'resume_652.txt': 5,
#  'resume_861.txt': 7,
#  'resume_875.txt': 10,
#  'resume_685.txt': 15,
#  'resume_849.txt': 11,
#  'resume_691.txt': 15,
#  'resume_478.txt': 6,
#  'resume_322.txt': 6,
#  'resume_444.txt': 26,
#  'resume_450.txt': 26,
#  'resume_336.txt': 6,
#  'resume_487.txt': 1,
#  'resume_493.txt': 12,
#  'resume_485.txt': 6,
#  'resume_491.txt': 12,
#  'resume_446.txt': 4,
#  'resume_320.txt': 6,
#  'resume_334.txt': 6,
#  'resume_452.txt': 4,
#  'resume_308.txt': 1,
#  'resume_687.txt': 7,
#  'resume_693.txt': 7,
#  'resume_863.txt': 7,
#  'resume_877.txt': 4,
#  'resume_122.txt': 7,
#  'resume_644.txt': 16,
#  'resume_888.txt': 7,
#  'resume_650.txt': 16,
#  'resume_136.txt': 21,
#  'resume_678.txt': 17,
#  'resume_11.txt': 4,
#  'resume_917.txt': 8,
#  'resume_39.txt': 12,
#  'resume_903.txt': 8,
#  'resume_730.txt': 7,
#  'resume_724.txt': 8,
#  'resume_718.txt': 11,
#  'resume_297.txt': 10,
#  'resume_283.txt': 2,
#  'resume_532.txt': 20,
#  'resume_254.txt': 3,
#  'resume_240.txt': 3,
#  'resume_526.txt': 50,
#  'resume_268.txt': 7,
#  'resume_269.txt': 5,
#  'resume_241.txt': 3,
#  'resume_527.txt': 36,
#  'resume_533.txt': 40,
#  'resume_255.txt': 3,
#  'resume_282.txt': 9,
#  'resume_296.txt': 1,
#  'resume_719.txt': 7,
#  'resume_725.txt': 10,
#  'resume_731.txt': 13,
#  'resume_902.txt': 6,
#  'resume_38.txt': 5,
#  'resume_916.txt': 6,
#  'resume_10.txt': 15,
#  'resume_679.txt': 15,
#  'resume_651.txt': 14,
#  'resume_889.txt': 4,
#  'resume_137.txt': 1,
#  'resume_123.txt': 4,
#  'resume_645.txt': 14,
#  'resume_876.txt': 7,
#  'resume_862.txt': 4,
#  'resume_692.txt': 21,
#  'resume_686.txt': 21,
#  'resume_309.txt': 10,
#  'resume_335.txt': 6,
#  'resume_453.txt': 3,
#  'resume_447.txt': 3,
#  'resume_321.txt': 6,
#  'resume_490.txt': 6,
#  'resume_484.txt': 2}

# %%
from app.services.parsing_service import ParsingService
from app.services.embedding_service import EmbeddingService

parser = ParsingService(data_dir="../data/resumes", chunk_size=400, chunk_overlap=50)
embedder = EmbeddingService()

# 1) get chunks per file
chunk_map = parser.parse_directory()  # Dict[str, List[Document]]

# print(chunk_map)
# 2) embed per file
stats: dict[str, int] = {}
for filename, chunks in chunk_map.items():
    if not chunks:
        stats[filename] = 0
        continue
    pairs = embedder.embed_documents(chunks)  # List[(np.ndarray, Document)]
    # You’ll pass these embeddings into your pgvector upsert next.
    stats[filename] = len(pairs)

print(stats)
# {'john_doe.pdf': 18, 'jane_doe.txt': 7, ...}
# Out:
# {'resume_489.txt': 2, 'resume_338.txt': 4, 'resume_304.txt': 12, 'resume_462.txt': 22, 'resume_476.txt': 7, 'resume_310.txt': 12, 'resume_847.txt': 10, 'resume_853.txt': 9, 'resume_884.txt': 4, 'resume_890.txt': 12, 'resume_648.txt': 16, 'resume_660.txt': 14, 'resume_106.txt': 27, 'resume_112.txt': 27, 'resume_674.txt': 11, 'resume_933.txt': 6, 'resume_927.txt': 3, 'resume_21.txt': 5, 'resume_35.txt': 3, 'resume_728.txt': 12, 'resume_714.txt': 13, 'resume_700.txt': 19, 'resume_258.txt': 6, 'resume_270.txt': 9, 'resume_516.txt': 23, 'resume_502.txt': 3, 'resume_264.txt': 5, 'resume_503.txt': 17, 'resume_265.txt': 2, 'resume_271.txt': 2, 'resume_517.txt': 52, 'resume_259.txt': 5, 'resume_701.txt': 25, 'resume_715.txt': 14, 'resume_729.txt': 13, 'resume_34.txt': 2, 'resume_20.txt': 19, 'resume_926.txt': 6, 'resume_932.txt': 3, 'resume_113.txt': 2, 'resume_675.txt': 14, 'resume_661.txt': 8, 'resume_107.txt': 2, 'resume_649.txt': 6, 'resume_891.txt': 7, 'resume_885.txt': 12, 'resume_852.txt': 5, 'resume_846.txt': 2, 'resume_477.txt': 22, 'resume_311.txt': 12, 'resume_305.txt': 12, 'resume_463.txt': 7, 'resume_339.txt': 5, 'resume_488.txt': 17, 'resume_449.txt': 18, 'resume_313.txt': 24, 'resume_475.txt': 22, 'resume_461.txt': 3, 'resume_307.txt': 24, 'resume_688.txt': 19, 'resume_850.txt': 26, 'resume_844.txt': 7, 'resume_878.txt': 9, 'resume_893.txt': 7, 'resume_139.txt': 5, 'resume_887.txt': 5, 'resume_677.txt': 13, 'resume_111.txt': 4, 'resume_105.txt': 4, 'resume_663.txt': 22, 'resume_924.txt': 10, 'resume_930.txt': 7, 'resume_36.txt': 7, 'resume_918.txt': 3, 'resume_22.txt': 7, 'resume_703.txt': 19, 'resume_717.txt': 12, 'resume_298.txt': 12, 'resume_529.txt': 52, 'resume_267.txt': 8, 'resume_501.txt': 16, 'resume_515.txt': 44, 'resume_273.txt': 8, 'resume_514.txt': 64, 'resume_272.txt': 3, 'resume_266.txt': 3, 'resume_500.txt': 7, 'resume_528.txt': 23, 'resume_299.txt': 12, 'resume_716.txt': 12, 'resume_702.txt': 8, 'resume_23.txt': 23, 'resume_919.txt': 6, 'resume_37.txt': 25, 'resume_931.txt': 10, 'resume_925.txt': 3, 'resume_104.txt': 7, 'resume_662.txt': 13, 'resume_676.txt': 8, 'resume_110.txt': 7, 'resume_138.txt': 3, 'resume_886.txt': 7, 'resume_892.txt': 3, 'resume_879.txt': 4, 'resume_845.txt': 4, 'resume_851.txt': 7, 'resume_689.txt': 25, 'resume_460.txt': 17, 'resume_306.txt': 3, 'resume_312.txt': 3, 'resume_474.txt': 3, 'resume_448.txt': 9, 'resume_470.txt': 18, 'resume_316.txt': 12, 'resume_302.txt': 2, 'resume_464.txt': 22, 'resume_458.txt': 22, 'resume_869.txt': 4, 'resume_855.txt': 12, 'resume_699.txt': 8, 'resume_841.txt': 2, 'resume_114.txt': 3, 'resume_672.txt': 13, 'resume_666.txt': 8, 'resume_100.txt': 3, 'resume_128.txt': 7, 'resume_896.txt': 10, 'resume_882.txt': 5, 'resume_33.txt': 23, 'resume_909.txt': 7, 'resume_27.txt': 25, 'resume_921.txt': 7, 'resume_935.txt': 7, 'resume_706.txt': 19, 'resume_712.txt': 13, 'resume_289.txt': 2, 'resume_504.txt': 2, 'resume_262.txt': 12, 'resume_276.txt': 9, 'resume_510.txt': 7, 'resume_538.txt': 64, 'resume_539.txt': 44, 'resume_277.txt': 2, 'resume_511.txt': 44, 'resume_505.txt': 7, 'resume_263.txt': 6, 'resume_288.txt': 9, 'resume_713.txt': 10, 'resume_707.txt': 25, 'resume_934.txt': 3, 'resume_920.txt': 3, 'resume_26.txt': 7, 'resume_908.txt': 7, 'resume_32.txt': 7, 'resume_883.txt': 9, 'resume_129.txt': 4, 'resume_897.txt': 3, 'resume_667.txt': 13, 'resume_101.txt': 4, 'resume_115.txt': 5, 'resume_673.txt': 22, 'resume_840.txt': 10, 'resume_698.txt': 25, 'resume_854.txt': 4, 'resume_868.txt': 9, 'resume_459.txt': 7, 'resume_303.txt': 12, 'resume_465.txt': 7, 'resume_471.txt': 22, 'resume_317.txt': 12, 'resume_498.txt': 17, 'resume_467.txt': 7, 'resume_301.txt': 24, 'resume_315.txt': 12, 'resume_473.txt': 17, 'resume_329.txt': 4, 'resume_842.txt': 16, 'resume_856.txt': 7, 'resume_103.txt': 1, 'resume_665.txt': 14, 'resume_671.txt': 8, 'resume_117.txt': 4, 'resume_881.txt': 7, 'resume_659.txt': 11, 'resume_895.txt': 7, 'resume_24.txt': 2, 'resume_30.txt': 19, 're ...

# %%
# !pip install -qU langchain-postgres langchain-huggingface sentence-transformers psycopg[binary]
from langchain_postgres import PGVector
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.schema import Document
import os

# 1) Embeddings (local, CPU-friendly)
emb = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")  # 384-dim. :contentReference[oaicite:2]{index=2}

# 2) Connect to your Aiven pgvector DB
CONN = os.environ["VECTOR_DB_URL"]  # e.g. postgresql://user:pass@host:port/db?sslmode=require

# 3) Create (or connect to) a vector store collection
#    By default PGVector will create needed tables if missing.
vs = PGVector(
    connection=CONN,
    collection_name="resumes",     # logical namespace
    embeddings=emb,                 # any LangChain Embeddings impl
)

# 4) Index: take your parsed chunks (LangChain Document list) and add
#    Example: chunks = ParsingService().parse_single("data/resumes/john.txt")
from app.services.parsing_service import ParsingService

parser = ParsingService()
chunks = parser.parse_single("../data/resumes/resume_1.txt")

# Ensure each chunk carries a useful source in metadata
for d in chunks:
    d.metadata.setdefault("source", "resume_1.txt")

# Add to the store (embeds under the hood)
ids = vs.add_documents(documents=chunks)
print(f"Inserted {len(ids)} chunks")

# 5) Search
docs = vs.similarity_search("keras", k=3)
for i, d in enumerate(docs, 1):
    print(f"\n[{i}] {d.metadata.get('source')} → {d.page_content[:200]}…")
# Out:
# Inserted 5 chunks
#
# [1] ../data/resumes/resume_1.txt → Data Scientist - Matelabs
# Skill Details
# Python- Exprience - Less than 1 year months
# Statsmodels- Exprience - 12 months
# AWS- Exprience - Less than 1 year months
# Machine learning- Exprience - Less than…
#
# [2] ../data/resumes/resume_1.txt → company - Matelabs
# description - ML Platform for business professionals, dummies and enthusiasts.
# 60/A Koramangala 5th block,
# Achievements/Tasks behind sukh sagar, Bengaluru,
# India                    …
#
# [3] ../data/resumes/resume_1.txt → company - Matelabs
# description -…

# %%
docs[0].page_content
# Out:
# 'Data Scientist - Matelabs\nSkill Details \nPython- Exprience - Less than 1 year months\nStatsmodels- Exprience - 12 months\nAWS- Exprience - Less than 1 year months\nMachine learning- Exprience - Less than 1 year months\nSklearn- Exprience - Less than 1 year months\nScipy- Exprience - Less than 1 year months\nKeras- Exprience - Less than 1 year monthsCompany Details \ncompany - Matelabs'

# %%
from google import genai
from dotenv import load_dotenv

# The client gets the API key from the environment variable `GEMINI_API_KEY`.

load_dotenv("../.env")
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI learns patterns from data to make decisions or predictions.

# %%
import os 
import sys 

sys.path.append(os.path.abspath("../backend/")) 

from app.services.resume_agent_service import ResumeAgent 
from dotenv import load_dotenv

load_dotenv("../.env")

agent = ResumeAgent()
response = agent.ask("What is the candidate's experience with machine learning?")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759953411.098750 3154096 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.

# %%
agent.ask("What is the candidate the most experienced with?")
# Out:
# 'The candidate is most experienced with Statsmodels, with 12 months of experience [source: ../data/resumes/resume_1.txt]. Other skills like Python, AWS, Machine Learning, Sklearn, Scipy, and Keras are listed with less than 1 year of experience [source: ../data/resumes/resume_1.txt].'

# %%
agent.ask("Does the candidate have a github page?")
# Out:
# 'Yes, the candidate has a GitHub page: github.com/rathorology [source: ../data/resumes/resume_1.txt].'
